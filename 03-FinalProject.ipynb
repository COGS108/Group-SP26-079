# %% [markdown]
# # The Effect of Transportation and Housing Barriers on Healthcare Access
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# - Shirley Yu: Background research, Conceptualization, Data, Writing – original draft, Visualization，Analysis, Experimental investigation
# - Yiwen Zhao: Background research, Research questions, Hypothesis, Data, Writing – original draft, Visualization, Writing – review & editing
# - Clara Gao: Research questions, Hypothesis, Ethics, Writing - original draft, visualization, writing - review & editing
# - Cecilia Ye: Analysis, Experimental investigation, Data curation, Visualization, Ethics, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do respondents’ delayed care due to unreliable transportation (boolean variable from survey) and housing vulnerability (Had trouble paying for housing? Residence owned or rented? Government paying part of rent?) affect their pattern of access healthcare (number of delayed medical care, number of ER visit, time since last saw doctor, general health status) in Delaware in 2024?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# According to the World Health Organization (WHO), Social Determinants of Health (SDOH), which refers to non-medical factors that influence health outcomes, include conditions such as socioeconomic status, education, neighborhood and geographic location, employment, and broader structural forces such as social policies and systemic inequality <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). In a large study of a hospital-based financial assistance program at Kaiser Permanente, researchers found that providing financial assistance significantly increased healthcare utilization, including outpatient visits, emergency department encounters, and inpatient care <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3).
#
# Within the system of SDOH, transportation and housing barriers are widely recognized as major obstacles to receiving healthcare, particularly among low-income populations and individuals with limited insurance coverage <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). Sixty-one studies across many states in the United States have shown that individuals without reliable transportation are more likely to miss appointments, delay care, or fail to receive recommended treatments <a name="cite_ref-4b"></a>[<sup>4</sup>](#cite_note-4). Similarly, a study of Medicaid patients in West Philadelphia, which is close to Delware, found that transportation difficulties were associated with missed primary care visits, particularly among low-income populations <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5). Through meta-analysis in the United States, Reid et al. found that individuals experiencing unstable housing are more likely to delay medical care, postpone medications, and experience difficulties accessing routine healthcare services. Housing instability has also been associated with fragmented healthcare utilization patterns and increased hospitalization rates <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6). These findings suggest that structural barriers, including both transportation and housing constraints, play a major role in shaping healthcare access and utilization patterns. So we choose Delware, where contains both urban and rural communities, as an area as interest to examine these structural barriers' effect.
#
# Nonetheless, a systematic review of non-emergency medical transportation interventions found that although some programs reduced missed appointments, evidence regarding healthcare utilization, costs, and long-term health outcomes remained limited and inconclusive <a name="cite_ref-7"></a>[<sup>7</sup>](#cite_note-7). Therefore, this project aims to examine and confirm how transportation-related barriers and housing vulnerability are associated with healthcare utilization patterns, highlighting the role of physical access in shaping general health outcomes.
#
#
# 1. <a name="cite_note-1"></a>“Social Determinants of Health.” *Centers for Disease Control and Prevention*, 16 May 2024,
#    <https://www.cdc.gov/public-health-gateway/php/about/social-determinants-of-health.html>
#
# 2. <a name="cite_note-2"></a>“Social Determinants of Health.” *World Health Organization*, 2024,
#    <https://www.who.int/health-topics/social-determinants-of-health#tab=tab_1>
#
# 3. <a name="cite_note-3"></a>Adams, Alyce, et al. “The Impact of Financial Assistance Programs on Health Care Utilization: Evidence from Kaiser Permanente.” *American Economic Review: Insights*, vol. 4, no. 3, 2022, pp. 389–407.
#    DOI: <https://doi.org/10.1257/aeri.20210515>
#
# 4. <a name="cite_note-4"></a>Syed, Samina T., et al. “Traveling towards Disease: Transportation Barriers to Health Care Access.” *Journal of Community Health*, vol. 38, no. 5, 2013, pp. 976–993.
#    DOI: <https://doi.org/10.1007/s10900-013-9681-1>
#
# 5. <a name="cite_note-5"></a>Chaiyachati, Krisda H., et al. “Association of Rideshare-Based Transportation Services and Missed Primary Care Appointments: A Clinical Trial.” *JAMA Internal Medicine*, vol. 178, no. 3, 2018, pp. 383–389.
#    PubMed Central: <https://pmc.ncbi.nlm.nih.gov/articles/PMC5975142/>
#
# 6. <a name="cite_note-6"></a>Reid, R. J., et al. “Association Between Housing Instability and Health Outcomes: A Meta-Analysis.” *Journal of Health Care for the Poor and Underserved*, vol. 19, no. 3, 2008, pp. 799–811.
#    PubMed: <https://pubmed.ncbi.nlm.nih.gov/19029747/>
#
# 7. <a name="cite_note-7"></a>Shekelle, Paul G., et al. “Effect of Interventions for Non-Emergent Medical Transportation: A Systematic Review and Meta-Analysis.” *BMC Public Health*, vol. 22, 2022, Article 799.
#    DOI: <https://doi.org/10.1186/s12889-022-13149-1>

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# The transportation barrier and housing vulnerability will affect the healthcare outcome. Populations with impeded transportation and uninsured housing may demonstrate a less frequent and standardized routine of accepting healthcare from hospitals and a worse general health status. High housing vulnerability may contribute more than high transportation barriers to the lower than average healthcare outcome.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# For this project, we use one public-use survey dataset: the 2024 National Health Interview Survey (NHIS) Sample Adult public-use file. NHIS is an annual U.S. household survey conducted by the National Center for Health Statistics. The unit of observation is one sampled U.S. adult respondent.
#
# - Dataset name: 2024 National Health Interview Survey (NHIS), Sample Adult public-use file
# - Dataset link: https://ftp.cdc.gov/pub/health_Statistics/nchs/Datasets/NHIS/2024/adult24csv.zip
# - Documentation/codebook: https://ftp.cdc.gov/pub/health_statistics/nchs/dataset_documentation/NHIS/2024/Adult-codebook.pdf
# - Raw dataset size: 32,629 sample adults and 630 raw variables
# - Cleaned analysis dataset: 28,917 sample adults and 20 selected/engineered variables
# - Cleaned file used for EDA: `data/02-processed/nhis_2024_sample_adult_cleaned.csv`
#
# The variables most relevant to our research question measure transportation barriers to care, housing strain, housing tenure, government rent assistance, delayed medical care, usual source of care, emergency-room use, time since last doctor visit, self-rated health, demographics, poverty ratio, insurance coverage, and NHIS survey design variables. Together, these variables allow us to examine whether transportation and housing-related vulnerability are associated with disruptions in a patient's healthcare journey.
#
# Important limitations are that NHIS is cross-sectional and self-reported, so the analysis can identify associations but cannot establish causality. Public-use NHIS also suppresses or recodes some sensitive information, including detailed geography, so we cannot directly analyze neighborhood-level conditions.

# %% [markdown]
# ### Dataset #1 (use name instead of number here)
#
# To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis.
#
# The 2024 NHIS Sample Adult file is appropriate for this project because it contains individual-level measures of healthcare access, transportation barriers, housing strain, insurance coverage, poverty, demographic characteristics, and general health status. The raw file is already rectangular, with one row per sampled adult and one column per survey variable. For this checkpoint, we use the cleaned analysis file created in the Data Checkpoint rather than forcing readers to re-run the full raw-data download and wrangling process.
#
# Key predictor variables include `transportation_barrier`, which indicates whether the respondent delayed care because they lacked reliable transportation; `housing_cost_trouble`, which indicates trouble paying housing costs; `housing_tenure`, which distinguishes owned, rented, and other arrangements; and `government_rent_assistance`, which indicates whether the government pays part of rent for renters. Key outcome variables include `delayed_medical_care`, `usual_place_care`, `any_er_visit`, `doctor_gap_yr`, and `general_health`. We also retain age, sex, race/ethnicity, education, poverty ratio, health insurance status, and NHIS survey design variables as controls or future weighting variables.
#
# Cleaning choices from the Data Checkpoint were carried forward here. NHIS uses numeric codes such as 7, 8, 9, 97, and 99 for refused, not ascertained, and don't know responses; these were converted to missing values before constructing analysis variables. Binary survey items coded as 1 = yes and 2 = no were standardized to 1 = yes and 0 = no. Categorical numeric codes were mapped to readable labels, including sex, race/ethnicity, education, health insurance, housing tenure, and usual place of care. Self-rated health was recoded so that higher values indicate better health. The government rent assistance item is structurally applicable to renters, so non-renters are coded as -1 rather than treated as true missingness. After these transformations, rows with remaining missing values in the selected analysis variables were dropped, leaving 28,917 observations.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import pandas as pd
import numpy as np
from matplotlib.pyplot import imread
import matplotlib.image as mpimg
from IPython.display import Image, display as ipy_display
import os
import matplotlib.pyplot as plt

processed_path = Path('data/02-processed/nhis_2024_sample_adult_cleaned.csv')
clean_nhis = pd.read_csv(processed_path)

print(f'Cleaned NHIS file loaded from: {processed_path}')
print(f'Cleaned shape: {clean_nhis.shape[0]:,} rows x {clean_nhis.shape[1]} columns')
display(clean_nhis.head())
# Out:
# Cleaned NHIS file loaded from: data/02-processed/nhis_2024_sample_adult_cleaned.csv
# Cleaned shape: 28,917 rows x 20 columns
#        HHX     WTFA_A  PSTRAT  PPSU  AGEP_A     sex      race_ethnicity  \
# 0  H067658   5780.565     122     2      49    Male  White non-Hispanic
# 1  H076577   3994.244     122     2      53    Male  White non-Hispanic
# 2  H019335   6636.755     122     2      82    Male  White non-Hispanic
# 3  H012701  13767.420     122     2      42    Male  White non-Hispanic
# 4  H049678  18880.030     115     1      38  Female  Black non-Hispanic
#
#    race_group                education  POVRATTC_A health_insurance  \
# 0  White only              AA academic        2.82        Uninsured
# 1  White only              AA academic        2.01          Insured
# 2  White only              AA academic        1.90          Insured
# 3  White only  Some college, no degree        4.48          Insured
# 4  Black only             Professional        6.37          Insured
# ...

# %%
variables_summary = pd.DataFrame([
    ['Predictor', 'transportation_barrier', 'Binary', '1 = delayed care because no reliable transportation'],
    ['Predictor', 'housing_cost_trouble', 'Binary', '1 = had trouble paying for housing'],
    ['Predictor', 'housing_tenure', 'Categorical', 'Owned/bought, rented, or other arrangement'],
    ['Predictor', 'government_rent_assistance', 'Categorical/Binary', '-1 = non-renter/not applicable, 0 = no assistance, 1 = receives assistance'],
    ['Outcome', 'delayed_medical_care', 'Binary', '1 = delayed medical care in past 12 months'],
    ['Outcome', 'usual_place_care', 'Categorical', 'Usual source of care status'],
    ['Outcome', 'any_er_visit', 'Count', 'Number of ER visits in past 12 months'],
    ['Outcome', 'doctor_gap_yr', 'Ordinal/count', 'Time since last doctor visit; larger values indicate longer gaps'],
    ['Outcome', 'general_health', 'Ordinal', '1 = poor through 5 = excellent'],
    ['Control', 'AGEP_A', 'Continuous', 'Age in years'],
    ['Control', 'sex', 'Categorical', 'Sex of respondent'],
    ['Control', 'race_ethnicity', 'Categorical', 'Race/ethnicity recode'],
    ['Control', 'race_group', 'Categorical', 'Race group recode'],
    ['Control', 'education', 'Categorical/ordinal', 'Highest educational attainment'],
    ['Control', 'POVRATTC_A', 'Continuous', 'Poverty ratio'],
    ['Control', 'health_insurance', 'Categorical', 'Insured vs uninsured'],
    ['Survey design', 'WTFA_A', 'Continuous', 'Final annual sample-adult weight'],
    ['Survey design', 'PSTRAT', 'Categorical', 'Pseudo-stratum'],
    ['Survey design', 'PPSU', 'Categorical', 'Pseudo-PSU']
], columns=['Role', 'Variable', 'Type', 'Description'])

display(variables_summary)

data_quality_summary = pd.DataFrame({
    'rows': [clean_nhis.shape[0]],
    'columns': [clean_nhis.shape[1]],
    'remaining_missing_values': [int(clean_nhis.isna().sum().sum())],
    'unique_household_ids': [clean_nhis['HHX'].nunique()]
})
display(data_quality_summary)

display(clean_nhis[['transportation_barrier', 'housing_cost_trouble', 'government_rent_assistance', 'delayed_medical_care']].mean().to_frame('mean_or_proportion'))
display(clean_nhis[['housing_tenure', 'usual_place_care', 'health_insurance']].describe(include='object'))
# Out:
#              Role                    Variable                 Type  \
# 0       Predictor      transportation_barrier               Binary
# 1       Predictor        housing_cost_trouble               Binary
# 2       Predictor              housing_tenure          Categorical
# 3       Predictor  government_rent_assistance   Categorical/Binary
# 4         Outcome        delayed_medical_care               Binary
# 5         Outcome            usual_place_care          Categorical
# 6         Outcome                any_er_visit                Count
# 7         Outcome               doctor_gap_yr        Ordinal/count
# 8         Outcome              general_health              Ordinal
# 9         Control                      AGEP_A           Continuous
# 10        Control                         sex          Categorical
# 11        Control              race_ethnicity          Categorical
# 12        Control                  race_group          Categorical
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# We performed EDA between all predictors and outcomes in the aformentioned table. We tested for significant difference across groups in the independent variable. If there is a significant differece, we then tested for its effect size to determine which variables we should use in the final model. We use Chi_square (categorical predictor vs. categorical outcomes) and Mann Whitney U test (categorical/biniary predictor vs. ordinal outcomes) to evaluate the effect of housing_tenure on 5 dependent variables. The housing_tenure columns contain a category of ‘Other arrangement', which is a vague definition, so we drop rows with 'Other arrangement' when analyze this specific independent variable.
# To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`.

# %% [markdown]
# #### Housing Tenure

# %% [markdown]
# A bar graph was generated to compare the proportion of individuals who experienced delayed medical care between house renters and homeowners. The Chi-square test examining the association between `housing_tenure` and `delayed_medical_care` produced a *p*-value approaching 0 and a Cohen’s *W* value below 0.1. These results indicate that renters are more likely to delay medical care compared with homeowners; however, the effect size is negligible, suggesting that the practical difference between groups is small despite statistical significance.
#
# According to the stacked bar plot and Chi-square statistics, the proportion of homeowners with a usual place of care was higher than that of renters, suggesting that homeowners are more likely to receive stable and continuous medical care. The Chi-square test yielded a *p*-value close to 0 and a Cohen’s *W* of 0.13, indicating that housing tenure has a small but statistically significant effect on whether an individual has a usual place of care.
#
# Additional stacked bar plots were generated to compare the distributions of:
# - number of ER visits,
# - years since last doctor visit, and
# - general health score
# between homeowners and renters. Mann–Whitney U tests showed statistically significant differences for all three outcomes, with *p*-values approaching 0.
#
# Based on the plots:
# - Renters visited the ER more frequently than homeowners, suggesting reduced access to continuous and preventive healthcare and a greater reliance on emergency services.
# - Renters tended to have longer gaps between doctor visits compared with homeowners.
# - Renters reported poorer general health scores overall.
#
# However, the rank-biserial correlation (RBC) values for all three Mann–Whitney U tests were below 0.1, indicating that although the differences were statistically significant, the effect sizes were negligible and the practical differences between the distributions were small. __The following are specific statistics and visualizations for each outcome:__

# %% [markdown]
# The proportion of homeowners with a usual place of care was higher than that of renters. Chi-square: *p* ≈ 0, Cohen's *W* = 0.13 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/tenure_usual_place_care.png'))

# %% [markdown]
# Renters are more likely to delay medical care than homeowners. Chi-square: *p* ≈ 0, Cohen's *W* < 0.1 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/tenure_delayed_medical_care.png'))

# %% [markdown]
# Renters visited the ER more frequently than homeowners. Mann–Whitney: *p* ≈ 0, RBC < 0.1 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/tenure_any_er_visit.png'))

# %% [markdown]
# Renters tended to have longer gaps between doctor visits. Mann–Whitney: *p* ≈ 0, RBC < 0.1 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/tenure_doctor_gap_yr.png'))

# %% [markdown]
# Renters reported poorer general health scores. Mann–Whitney: *p* ≈ 0, RBC < 0.1 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/tenure_general_health.png'))

# %% [markdown]
# #### Government Rent Assistance

# %% [markdown]
# Because `government_rent_assistance` is only meaningful for renters, we first check how it overlaps with `housing_tenure`. In this cleaned dataset, owners and people in other arrangements are coded as `-1` for rent assistance, while renters are coded as either receiving assistance or not receiving assistance. This means the main comparison should be made within renters instead of across all housing tenure groups. Among renters, government rent assistance appears to separate a more economically vulnerable subgroup from other renters. Renters receiving assistance have a higher rate of housing cost trouble and lower average general health, but they also show a higher probability of having a usual place of care and a lower rate of delayed medical care. This mixed pattern suggests that rent assistance may be associated with both greater baseline need and better connection to support systems, so later modeling should control for demographics, insurance, income ratio, and health status before making any causal interpretation.
# __The following are specific statistics and visualizations for each outcome:__

# %% [markdown]
# ~85% of renters report no assistance and ~15% receive assistance. Non-renters are coded as not applicable.

# %%
ipy_display(Image(filename='results/eda_charts/rent_assistance_by_tenure.png'))

# %% [markdown]
# Among renters, those receiving assistance show lower delayed care rates and higher usual place of care rates, but also lower general health scores — consistent with a higher-need subgroup.

# %%
ipy_display(Image(filename='results/eda_charts/rent_assistance_outcomes_panel.png'))

# %% [markdown]
# General health distribution among renters by assistance status. Renters with assistance have a higher proportion of Poor/Fair health responses.

# %%
ipy_display(Image(filename='results/eda_charts/rent_assistance_general_health_dist.png'))

# %% [markdown]
# #### Housing Cost Trouble

# %% [markdown]
# In the following section, we used paired and stacked bar plot to visualize the relationships between our predictor (housing cost troubles, binary) and outcomes (delayed medical care (binary), usual place of care (categorical), any er visit (count), doctor gap yr(count), general health score (ranked)). We tested for significance and effect size.
#
# Overall, housing cost trouble was significantly associated with multiple healthcare access and health outcome variables. Although many of the statistical tests produced extremely small p-values, indicating strong evidence of association, most effect sizes were small or negligible, suggesting that the practical strength of these relationships is modest. Among the outcomes examined, delayed medical care and general health showed the strongest associations with housing cost trouble, while usual place of care and doctor gap year demonstrated minimal practical effect despite statistical significance. These findings suggest that housing-related financial strain is linked to barriers in healthcare access and poorer self-reported health, though the magnitude of these effects varies across outcomes.
#
# __The following are specific statistics and visualizations for each outcome:__

# %% [markdown]
# Those with housing cost trouble are more likely to delay care. Chi-square: *p* = 1.68 × 10⁻²²⁵, Cramér's *V* = 0.1885 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/hcost_delayed_medical_care.png'))

# %% [markdown]
# Those with housing cost trouble are slightly more likely to lack a usual place of care. Chi-square: *p* = 1.00 × 10⁻⁸, Cramér's *V* = 0.0357 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/hcost_usual_place_care.png'))

# %% [markdown]
# Those with housing cost trouble have more ER visits. Mann–Whitney: *p* = 1.52 × 10⁻⁸⁶, RBC = −0.1933 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/hcost_any_er_visit.png'))

# %% [markdown]
# Those with housing cost trouble have a slightly higher mean doctor gap year, with higher variance. Mann–Whitney: *p* = 3.68 × 10⁻⁶, RBC = −0.0362 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/hcost_doctor_gap_yr.png'))

# %% [markdown]
# Those with housing cost trouble report worse general health. Mann–Whitney: *p* = 3.69 × 10⁻⁹³, RBC = 0.2698 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/hcost_general_health.png'))

# %% [markdown]
# #### Transportation Barrier

# %% [markdown]
# In the following section, we used bar plots and stacked bar plots to visualize the relationships between `transportation_barrier` (binary: `0 = no barrier`, `1 = has barrier`) and five outcome variables. We applied Chi-square tests for categorical outcomes and Mann–Whitney U tests for ordinal/count outcomes, with Cohen's *W* and rank-biserial correlation (RBC) as effect size measures.
# Overall, transportation barrier was significantly associated with all five outcomes. However, most effect sizes were small to negligible, indicating that although the associations are statistically reliable, their practical magnitude is generally modest.
# __The following are specific statistics and visualizations for each outcome:__

# %% [markdown]
# ~19.5% of the Has Barrier group delayed care vs. 6.9% of No Barrier — roughly a threefold difference. Chi-square: χ²(1) = 363.49, *p* = 4.89 × 10⁻⁸¹, Cohen's *W* = 0.1121 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/transport_delayed_medical_care.png'))

# %% [markdown]
# Has Barrier group has a slightly lower proportion with a usual care source (~85% vs ~91%). Chi-square: χ²(2) = 37.35, *p* = 7.77 × 10⁻⁹, Cohen's *W* = 0.0359 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/transport_usual_place_care.png'))

# %% [markdown]
# Has Barrier group has fewer zero-visit respondents (~64% vs ~79%), suggesting greater reliance on emergency services. Mann–Whitney: *U* = 19,536,848.5, *p* = 4.72 × 10⁻⁶⁰, RBC = 0.1674 (small effect).

# %%
ipy_display(Image(filename='results/eda_charts/transport_any_er_visit.png'))

# %% [markdown]
# The two groups have nearly identical distributions. Mann–Whitney: *U* = 22,978,820.5, *p* = 1.10 × 10⁻², RBC = 0.0208 (negligible effect).

# %%
ipy_display(Image(filename='results/eda_charts/transport_doctor_gap_yr.png'))

# %% [markdown]
# Has Barrier group has substantially more Poor/Fair responses; No Barrier group skews toward Very Good/Excellent. Mann–Whitney: *U* = 30,086,380.0, *p* = 2.58 × 10⁻⁹³, RBC = −0.2821 (small-to-medium effect).

# %%
ipy_display(Image(filename='results/eda_charts/transport_general_health.png'))

# %% [markdown]
# ### Count Model: Healthcare Access Disruption Score
#
# To see the code responsible for Data analyses after EDA analysis see `Data Analysis -2nd part.ipynb`.
#
# We constructed an `access_disruption_score` from five indicators: delayed medical care, not having a usual place of care, at least one ER visit, more than one year since last doctor visit, and poor/fair self-rated health.
# The access disruption score is a composite count variable summing five binary indicators (0 or 1 each), yielding a possible range of 0–5:
#
# | Component | Coded as 1 if… |
# |---|---|
# | Delayed medical care | Reported delaying care |
# | Usual place of care | No single or no usual place of care |
# | ER visit | One or more ER visits in the past year |
# | Doctor gap | More than one year since last doctor visit |
# | General health | Fair or poor self-rated health |
#
# A higher score indicates greater disruption to healthcare access.
# The score ranges from 0 to 5 (only 3 individuals in the sample get a score of 5), where higher values indicate more healthcare access disruption.

# %%
dist = pd.read_csv('results/access_disruption_score_distribution.csv')
print('Access Disruption Score Distribution and Summary \n')
print(dist.round(4))
summ=pd.read_csv('results/access_disruption_score_summary.csv')
print('\n',summ.round(4))
# Out:
# Access Disruption Score Distribution and Summary
#
#    access_disruption_score      n  percent
# 0                        0  15009  51.9037
# 1                        1   9233  31.9293
# 2                        2   3846  13.3001
# 3                        3    738   2.5521
# 4                        4     88   0.3043
# 5                        5      3   0.0104
#
#       mean  variance  min  max
# 0  0.6746    0.6773    0    5

# %% [markdown]
# We first use Logistic Regression to build classification model, but the unbalanced class lead to low accuracy, even with stratifying and survey weights, according to the confusion matrix ('results/classification_confusion_matrix.png') and classification report ('results/access_disruption_score_summary.csv'). For this reason, a preliminary generalized linear model (GLM) using Poisson regression with robust standard errors was fitted to assess the overall direction of key predictors. This keeps the model interpretable while avoiding the class-imbalance problem from the binary logistic regression.

# %%
full_key_results = pd.read_csv('results/access_disruption_poisson_key_results.csv', index_col=False)
full_key_results.at[0,'term'] = 'Other arrangement'
full_key_results.at[1,'term'] = 'Rented'
full_key_results.round(4)
# Out:
#                  model                        term    coef     IRR  CI_lower  \
# 0  Full sample Poisson           Other arrangement  0.2179  1.2435    1.1493
# 1  Full sample Poisson                      Rented  0.2242  1.2513    1.2135
# 2  Full sample Poisson      transportation_barrier  0.2940  1.3417    1.2839
# 3  Full sample Poisson        housing_cost_trouble  0.3278  1.3879    1.3318
# 4  Renter-only Poisson      transportation_barrier  0.3079  1.3605    1.2837
# 5  Renter-only Poisson        housing_cost_trouble  0.2513  1.2857    1.2169
# 6  Renter-only Poisson  government_rent_assistance  0.0570  1.0586    0.9986
#
#    CI_upper  p_value
# 0    1.3455   0.0000
# 1    1.2903   0.0000
# 2    1.4022   0.0000
# 3    1.4465   0.0000
# 4    1.4420   0.0000
# 5    1.3583   0.0000
# 6    1.1223   0.0558

# %% [markdown]
# The Poisson model gives a more detailed result and trend compared to exploratory analysis. Incident Rate Ratios (IRR) reflect the relative rate of a count outcome, with above 1 indicate increased rate and below 1 indicate decreased rate relative to the reference group. After adjusting for controls (age, poverty ratio, sex, race/ethnicity, education, and insurance), respondents with a transportation barrier had about **34% higher expected healthcare access disruption** than respondents without that barrier (IRR = 1.34, 95% CI [1.28, 1.40], p < 0.001). Respondents who had trouble paying housing costs had about **39% higher expected disruption** (IRR = 1.39, 95% CI [1.33, 1.45], p < 0.001). Compared with homeowners, renters had about **25% higher expected disruption** (IRR = 1.25, 95% CI [1.21, 1.29], p < 0.001).
#
# Since the government rent assistance predictor only applied to renters, we stratified the sample to generate the renter only dataset to analyze. As a renter-only reliability check, government rent assistance was associated with a small increase in expected disruption, but this estimate was only borderline significant (IRR = 1.06, 95% CI [1.00, 1.12], p = 0.056). This suggests rent assistance may identify a more vulnerable subgroup of renters, but it is not as strong or stable a predictor as transportation barriers and housing cost trouble. Overall, this model appears more appropriate than a classification model because it preserves the direction and magnitude of the housing and transportation effects without being dominated by the majority class.

# %%
forest = mpimg.imread('results/access_disruption_irr_forest_plot.png')
plt.imshow(forest)
plt.axis('off')
plt.show()

# %% [markdown]
# **Figure caption.** This forest plot shows the incidence rate ratio (IRR) for each key predictor in the Poisson model. The horizontal axis is the IRR: values above 1 indicate higher expected healthcare access disruption compared with the reference group. `Transportation barrier` compares respondents who delayed care because of unreliable transportation with those who did not. `Housing cost trouble` compares respondents who had trouble paying housing costs with those who did not. `Rented vs owned` compares renters with respondents who owned or were buying their homes. `Other tenure vs owned` compares respondents in other housing arrangements with homeowners.

# %% [markdown]
# ### Additional Analyses Addressing Specific Aspects of the Outcomes
#
# The main count model summarizes overall healthcare access disruption, but our research question includes several distinct aspects of healthcare access and health status. To avoid relying on a single composite outcome, we use Poisson GLM for count outcomes (doctor_gap_yr, any_er_visit, general_health) and binomial GLM for binary or categorical outcomes (delayed_medical_care, usual_palace_care) to inspect each outcome's regression model with predictors.

# %%
aspect=pd.read_csv('results/aspect_key_results.csv').round(4)
term_map = {
    'C(housing_tenure, Treatment(reference="Owned or being bought"))[T.Rented]': 'Renter',
    'C(housing_tenure, Treatment(reference="Owned or being bought"))[T.Other arrangement]': 'Other arrangement'
}
aspect['term'] = aspect['term'].replace(term_map)
aspect
# Out:
#                                           model                        term  \
# 0   Full sample Logistic – delayed_medical_care           Other arrangement
# 1   Full sample Logistic – delayed_medical_care                      Renter
# 2   Full sample Logistic – delayed_medical_care      transportation_barrier
# 3   Full sample Logistic – delayed_medical_care        housing_cost_trouble
# 4   Renter-only Logistic – delayed_medical_care      transportation_barrier
# 5   Renter-only Logistic – delayed_medical_care        housing_cost_trouble
# 6   Renter-only Logistic – delayed_medical_care  government_rent_assistance
# 7        Full sample Logistic – has_usual_place           Other arrangement
# 8        Full sample Logistic – has_usual_place                      Renter
# 9        Full sample Logistic – has_usual_place      transportation_barrier
# 10       Full sample Logistic – has_usual_place        housing_cost_trouble
# ...

# %% [markdown]
# Odds Ratios (OR) reflect the relative odds of a binary outcome occurring, where odds represent the ratio of the probability of an event happening to it not happening, with above 1 indicate increased odds and below 1 indicate decreased odds relative to the reference group. Across all five outcomes, housing cost trouble emerged as the stronger and more consistent predictor than transportation barriers: it nearly triples the odds of delayed care (OR 3.28) and substantially raises ER visit rates (IRR 1.66), while transportation barriers show meaningful but smaller effects in the same direction. Renter status is associated with worse outcomes across the board compared to owners — lower odds of having a usual place of care (OR 0.63) and higher ER utilization (IRR 1.26) — though effects on doctor gap years and general health are modest. Doctor gap year showed generally small, mostly non-significant associations with housing and transportation predictors, suggesting these barriers affect care access and utilization more than appointment frequency. Importantly, each predictor — transportation barrier, housing cost trouble, housing tenure, and government rent assistance — significantly affects at least one outcome, confirming that all of them meaningfully contribute to the variation in the overall access disruption score at this stage of analysis.
# The mixed pattern of rent assistance observed in the individual outcome models — protective for care access outcomes but associated with higher ER utilization and worse health scores — is consistent with the main model finding that rent assistance identifies a more vulnerable renter subgroup rather than acting as a strong independent predictor, supporting the interpretation that recipients tend to have greater underlying need.

# %% [markdown]
# ### Examine the dataset with most dominant ethnicity (White non-Hispanic) removed

# %% [markdown]
# The white non-Hispanic ethnicity compose the majority of the sample. To examine whether the patterns between predictors and outcomes in other ethnicities are hidden by the pattern in white non-Hispanic population, and whether there's difference in housing and transportation's effect between the major population in Delware (white non-Hispanic) and the minor populations, we substract white non-Hispanic individuals from datasets to perform Poisson regression.

# %%
nonwhite_key_results = pd.read_csv('results/access_non-white_subsample_key_poisson_results.csv', index_col=False)
nonwhite_key_results.at[0,'term'] = 'Other arrangement'
nonwhite_key_results.at[1,'term'] = 'Rented'
nonwhite_key_results.round(4)
# Out:
#                           model                        term    coef     IRR  \
# 0           Non-white subsample           Other arrangement  0.1553  1.1680
# 1           Non-white subsample                      Rented  0.1615  1.1752
# 2           Non-white subsample      transportation_barrier  0.2589  1.2956
# 3           Non-white subsample        housing_cost_trouble  0.2742  1.3155
# 4  Nonwhite_renter-only Poisson      transportation_barrier  0.2646  1.3029
# 5  Nonwhite_renter-only Poisson        housing_cost_trouble  0.1883  1.2072
# 6  Nonwhite_renter-only Poisson  government_rent_assistance  0.0879  1.0919
#
#    CI_lower  CI_upper  p_value
# 0    1.0045    1.3582   0.0436
# 1    1.1159    1.2376   0.0000
# 2    1.2082    1.3892   0.0000
# 3    1.2337    1.4027   0.0000
# 4    1.1959    1.4194   0.0000
# 5    1.1159    1.3061   0.0000
# 6    1.0031    1.1886   0.0422

# %% [markdown]
# After removing the `white non-Hispanic` from the samples, the model still predicts that populations without ownership of house, have transportation barrier, and have housing cost trouble will increase the disruption score, according to larger than 1 IRR value and less than 0.05 p_value for most predictors. Therefore, a similar pattern between socioeconomic predictors and access disruption score in the survey both exists for full population and population that only contain minor ethnicity. However, the IRR score for each predictor is generally lower than those from models of the full sample, indicating that the race ethnicity will affect how housing and transportation impact people's access of healthcare. Specifically, transportation and housing condition may have less effect on non-white population than white-population, but further analysis is needed to make the conclusion and prove that the difference is not due to chance.

# %% [markdown]
# ### Prediction: Expected Healthcare Access Disruption
#
# According to previous analysis, each predictor significantly affects at least 1 outcomes, so all of them contribute to the variation of the access disruption score at this stage of analysis. Also, the pattern we observed in the the model exists for both the dominant ethnicity and minors. Therefore, the Poisson GLM on the full dataset is relatively fair and can be potentially used for prediction. We used Poisson GLM to predict access disruption score for scenarios. We compared the Poisson GLM against a Train Mean baseline model that predicts the average Access Disruption Score for all respondents. Unlike the baseline, the Poisson GLM incorporates predictors to generate individualized predictions. The comparison allows us to evaluate whether these social determinants provide meaningful information beyond the overall population average.

# %%
predicted_results = pd.read_csv('results/access_disruption_prediction_performance.csv', index_col=False)
scenario_prediction = pd.read_csv('results/access_disruption_scenario_predictions.csv', index_col=False)
print(predicted_results.round(4))
scenario_prediction.round(4)
# Out:
#                  model     MAE    RMSE  test_n
# 0          Poisson GLM  0.6495  0.7769    5759
# 1  Train-mean baseline  0.7079  0.8337    5759
#                                    scenario  transportation_barrier  \
# 0      No transportation or housing barrier                     0.0
# 1               Transportation barrier only                     1.0
# 2                 Housing cost trouble only                     0.0
# 3  Both transportation and housing barriers                     1.0
# 4                 Renter, no listed barrier                     0.0
# 5                 Renter with both barriers                     1.0
#
#    housing_cost_trouble         housing_tenure  \
# 0                   0.0  Owned or being bought
# 1                   0.0  Owned or being bought
# 2                   1.0  Owned or being bought
# 3                   1.0  Owned or being bought
# 4                   0.0                 Rented
# 5                   1.0                 Rented
#
# ...

# %% [markdown]
# The prediction results show that the Poisson GLM performs slightly better than a simple baseline that predicts the training-set mean for every person. On the test set, the model reduced MAE from 0.708 to 0.650 and RMSE from 0.834 to 0.777. Due to the modest improvement, we could conclude that housing and transportation factors contribute to explaining variation in healthcare disruption but should not frame the model as a strong individual-level prediction tool.
#
# The scenario predictions are more useful for interpretation. For a typical insured respondent with median age and poverty ratio, the expected access disruption score is about **0.51** when there is no transportation or housing barrier. With a transportation barrier only, the expected score rises to **0.68**. With housing cost trouble only, it rises to **0.71**. With both barriers, it rises to **0.95**. If the person is also a renter, the expected score rises further to about **1.19**. In plain terms, the model predicts that overlapping transportation and housing barriers create substantially higher expected healthcare access disruption than either barrier alone.

# %%
bar = mpimg.imread('results/access_disruption_scenario_predictions.png')
plt.imshow(bar)
plt.axis('off')
plt.show()

# %% [markdown]
# **Figure caption.** This bar chart shows the model-predicted access disruption score for typical respondent profiles. `No barrier` means no transportation barrier, no housing cost trouble, and owned/being bought housing. `Transport only` means the respondent has a transportation barrier but no housing cost trouble. `Housing only` means the respondent has housing cost trouble but no transportation barrier. `Both barriers` means both transportation and housing cost barriers are present. `Renter only` means rented housing without the two listed barriers. `Renter + both` means rented housing plus both transportation and housing cost barriers.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# > The data is collected via telephone, which excludes people without phone access who may be more likely to experience those low housing condition and inconvenient transportation. Institutionalized, unhoused people are also underrepresented in the survey. Therefore, the result of the survey may underestimate the effect of these barriers on the most ‘vulnerable’ people.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
# > Although the BRFSS dataset is publicly released in de-identified form, since the survey collects data in a small state, the combination of variables in our analysis creates a risk of quasi-identification. To mitigate this, we commit to the following: we will only report group-level statistics and model outputs, not individual-level responses; we will not attempt to cross-reference BRFSS records with any external dataset.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#         Considering it’s an already posted survey, the individual cannot ask for removal. This is a limitation of the analysis
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > The BRFSS relies on self-reported responses, which are subject to recall bias and hide the sensitive information. Also, the estimation of housing vulnerability is based on a combination of many variables instead of a direct measurement, where we may overestimate or underestimate some of the aspect.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > All data cleaning steps and modeling choices will be documented in our Github with annotation, so that our analysis is fully reproducible and open to scrutiny.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
# > We acknowledge that variables representing socioeconomic status or geographic location can often mirror sensitive demographic data. We have taken care to ensure that our model focuses on identifying structural barriers rather than creating a tool that could be used to categorize or discriminate against specific populations based on where they live or their financial status.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > Our team has considered the potential for disparate outcomes across different groups. Since our housing vulnerability index is based on variables that correlate with race and income, there is a risk that downstream users treat the conclusion as a measurement of personal ‘riskiness’. Moreover, when applied in local policy, if policymakers interpret our results as evidence that individuals with transportation barriers are simply "less likely to seek care," this framing could be used to justify reducing healthcare services in affected areas. To prevent this, we will explicitly frame all findings in terms of structural barriers, not individual behavior or personal failure; include a dedicated section in our final report discussing how results should and should not be applied in policies; and acknowledge that our cross-sectional design shouldn’t establish that transportation barriers cause forgone care.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# >  We have selected metrics that best represent the challenges of accessibility and vulnerability. We recognize that no single metric can capture the full complexity of a person's life, so we have balanced our primary measurements with broader indicators to ensure our results provide a well-rounded perspective rather than an oversimplified view of the problem.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
# > We have prioritized clarity in our modeling process so that the logic behind our conclusions can be easily understood by non-technical audiences. By avoiding overly complex "black-box" methods, we ensure that our results are transparent and that the factors influencing our findings are clear to anyone reviewing the project.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# > We are committed to being honest about what our data can and cannot tell us. We have documented the inherent biases in survey-based research and the limitations of our scope. By communicating these uncertainties, we ensure that our analysis is used as a helpful guide rather than an absolute conclusion.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
# > if the findings of this project were to be implemented in a real-world setting, we recommend ongoing review to ensure the intended goals are being met. This includes monitoring whether the proposed solutions are actually helping the target populations and making adjustments if the data reveals new trends or unexpected outcomes over time.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > We have considered how this information might be used outside of its original intent. To prevent potential misuse, we advocate for the findings to be used exclusively for supportive public measures, such as improving community resources, rather than for any purpose that could negatively impact the privacy or stability of the communities involved.

# %% [markdown]
# ## Discusison and Conclusion

# %% [markdown]
# ### Conclusion
#
# This study use basic exploratory analysis (Chi-square, Mann Whitney U test) and inferential and predictive model (GLM) to approach the 2024 NHIS survey, and the results from models generally accord wit the exploratory analysis. The study found that housing and transportation barriers are consistently associated with reduced healthcare access and poorer health outcomes, and they also independently contribute to health access outcomes. Across multiple healthcare access measures, individuals experiencing housing cost burden, transportation barriers, or lacking home ownership were more likely to experience disruptions in care. Poisson Regression analysis further showed that transportation barriers, housing cost burden, and non-homeownership were associated with approximately 30% higher Access Disruption Scores, while government rent assistance contribute to a small increase in the scores.
#
# Overall, these findings reinforce the importance of Social Determinants of Health in shaping healthcare utilization. The results suggest that improving housing stability and reducing transportation barriers may be important strategies for increasing healthcare access and reducing health disparities. Moreover, the greater disruption observed when multiple barriers co-occur highlights the need for interventions that address socioeconomic challenges in combination rather than in isolation.
#
# ### Discussion
#
# This study extends prior research on Social Determinants of Health (SDOH) by examining how housing and transportation barriers are associated with healthcare access outcomes in Delaware. Previous studies have shown that transportation difficulties contribute to missed appointments and delayed care, while housing instability is linked to fragmented healthcare utilization and poorer health outcomes. Our findings support these conclusions and provide quantitative estimates of their relative impact using NHIS data.
#
# The exploratory analyses demonstrated that housing tenure, transportation barriers, housing cost burden, and government housing assistance were all significantly associated with healthcare access outcomes, including years since last doctor visit, emergency room utilization, delayed medical care, usual place of care, and self-reported health status. Although many individual associations had small effect sizes, the consistency of the relationships across multiple outcomes suggests that these socioeconomic factors play an important role in shaping healthcare utilization patterns.
#
# To summarize overall healthcare accessibility, we constructed an Access Disruption Score and modeled it using Poisson Regression. Transportation barriers, housing cost burden, and non-homeownership were each associated with approximately 30% higher expected disruption scores. These findings are consistent with the literature reviewed in the Background section. Syed et al. (2013) reported that transportation barriers consistently reduce healthcare utilization, while Reid et al. (2008) found that housing instability is associated with fragmented patterns of care. Our results provide additional evidence supporting these conclusions within a Delaware population. Unexpectedly, we found government housing assistance was associated with a small increase in the Access Disruption Score, which is likely reflects the greater underlying socioeconomic challenges faced by assistance recipients rather than a negative effect of the program itself. Further longitudinal research is needed to evaluate the causal impact of housing assistance on healthcare access.
#
# One particularly notable finding through Poisson GLM was that the combined presence of housing cost burden and transportation barriers was associated with greater healthcare disruption than either factor alone. This suggests that multiple socioeconomic disadvantages may interact or accumulate, creating additional obstacles to healthcare access. Rather than acting independently, housing and transportation conditions may jointly influence an individual's ability to obtain timely and consistent medical care.
#
# The analysis of the Non-White sample subset produced results that were broadly consistent with those observed in the full sample, indicating that housing and transportation barriers remain important predictors of healthcare access across racial and ethnic groups. However, the estimated effects were somewhat smaller among Non-White respondents. Several explanations are possible. The smaller subgroup sample size may have reduced statistical power, making effect estimates less stable. Alternatively, differences in social support systems, healthcare-seeking behaviors, or community resources may partially buffer the impact of housing and transportation barriers. Because formal interaction analyses were not conducted, these explanations remain speculative and warrant further investigation.
#
# Several limitations should be considered when interpreting these findings. First, the dataset has classes that are highly imbalanced due to the non even distribution of people with different conditions in the population. Second, NHIS data are cross-sectional, preventing conclusions about causality. Poor health may contribute to housing instability or transportation difficulties just as easily as these barriers may contribute to poor healthcare access. Third, all measures were self-reported and therefore subject to recall and reporting bias. Fourth, survey-based sampling may underrepresent highly vulnerable populations, including unhoused individuals, people without reliable phone access, and institutionalized populations. As these groups are likely to experience the greatest transportation and housing challenges, the true effects may be larger than those estimated in this study. Finally, the public-use NHIS dataset suppresses detailed geographic information, limiting the ability to investigate neighborhood-level or community-level variation.
#
# Future research should focus on linking survey data with administrative healthcare records to validate self-reported outcomes and improve measurement accuracy. Longitudinal studies would also be valuable because they could determine whether changes in housing or transportation conditions precede changes in healthcare utilization, helping establish causal relationships that cannot be identified using cross-sectional data alone.
